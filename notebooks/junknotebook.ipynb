# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
loss = torch.load("/home/alex/Documents/InformationHeuristic/weights/cifar100/representations/barlowtwin/barlowtwin_resnet18_2.50/loss_history.pt")

# %%
plt.plot(loss[:])
